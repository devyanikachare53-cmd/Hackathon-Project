# %% [markdown]
# <a href="https://colab.research.google.com/github/devyanikachare53-cmd/Hackathon-Project/blob/master/Medical_Symptom_dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files

# %%
uploaded  = files.upload()
# Out:
#      <input type="file" id="files-1984c67c-10fe-44fc-97df-1654460285dc" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-1984c67c-10fe-44fc-97df-1654460285dc">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
df = pd.read_csv('dataset1.csv')

# %%
df
# Out:
#            Fever  Headache     Cough   Fatigue  Body_Pain       Disease
# 0      98.283156  4.118632  2.687983  4.116661   8.470956     Body Ache
# 1      98.284660  6.963971  1.960734  5.495257   8.033919     Body Ache
# 2     103.622552  8.702915  2.854463  6.546993   2.205383       Malaria
# 3      98.254732  1.354851  5.880676  5.418289   2.695560   Common Cold
# 4      97.182670  0.357962  6.206723  4.488365   1.406323         Cough
# ...          ...       ...       ...       ...        ...           ...
# 4995   99.497722  2.172020  0.586186  4.632525   1.605553  Normal Fever
# 4996  101.723742  5.895228  2.136698  4.763550   1.093120  Normal Fever
# 4997  103.112569  7.834451  1.006200  9.094380   5.438879        Dengue
# 4998   97.432053  1.613986  1.826666  2.089975   1.247891    Runny Nose
# 4999   97.661094  1.994773  5.155273  4.701630   1.799597   Common Cold
#
# [5000 rows x 6 columns]

# %%
df.shape
# Out:
# (5000, 6)

# %%
df.head()
# Out:
#         Fever  Headache     Cough   Fatigue  Body_Pain      Disease
# 0   98.283156  4.118632  2.687983  4.116661   8.470956    Body Ache
# 1   98.284660  6.963971  1.960734  5.495257   8.033919    Body Ache
# 2  103.622552  8.702915  2.854463  6.546993   2.205383      Malaria
# 3   98.254732  1.354851  5.880676  5.418289   2.695560  Common Cold
# 4   97.182670  0.357962  6.206723  4.488365   1.406323        Cough

# %%
print("\nColumns:")
print(df.columns)
# Out:
# Columns:
# Index(['Fever', 'Headache', 'Cough', 'Fatigue', 'Body_Pain', 'Disease'], dtype='object')

# %%
print("\nDisease counts:")
print(df["Disease"].value_counts())
# Out:
# Disease counts:
# Disease
# Body Ache       625
# Malaria         625
# Common Cold     625
# Cough           625
# Normal Fever    625
# Dengue          625
# Asthma          625
# Runny Nose      625
# Name: count, dtype: int64

# %%
print("Missing value :")
df.isnull().sum()
# Out:
# Missing value :
# Fever        0
# Headache     0
# Cough        0
# Fatigue      0
# Body_Pain    0
# Disease      0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Fever      5000 non-null   float64
#  1   Headache   5000 non-null   float64
#  2   Cough      5000 non-null   float64
#  3   Fatigue    5000 non-null   float64
#  4   Body_Pain  5000 non-null   float64
#  5   Disease    5000 non-null   object
# dtypes: float64(5), object(1)
# memory usage: 234.5+ KB

# %%
import seaborn as sns

corr = df.corr(numeric_only=True)

plt.figure(figsize=(8,6))
sns.heatmap(corr, annot=True, cmap='coolwarm')
plt.title("Correlation Heatmap")
# Out:
# Text(0.5, 1.0, 'Correlation Heatmap')

# %%
import matplotlib.pyplot as plt

df["Disease"].value_counts().plot(
    kind="bar",
    figsize=(10, 6)
)

plt.title("Disease Distribution")
plt.xlabel("Disease")
plt.ylabel("Count")
plt.xticks(rotation=45)

plt.show()

# %%
for column in df.columns:
    print("\n", column)
    print(df[column].unique()[:20])
# Out:
#  Fever
# [ 98.28315625  98.28466015 103.6225524   98.25473174  97.18267026
#   99.84319244  98.36190418  97.92445373  99.42270799  99.85717952
#   97.1495555   98.84708226 104.8278129  104.16418141 100.26790303
#  100.38046266  98.31490598  99.56934636  98.33897896  97.46453124]
#
#  Headache
# [4.11863151 6.96397103 8.70291458 1.35485057 0.35796161 3.15030232
#  4.52443693 4.68897135 5.86893232 2.13986324 0.21148611 6.56168237
#  7.6905001  9.97354204 4.90982602 5.17627955 2.70628682 4.82380647
#  4.57997947 1.44141463]
#
#  Cough
# [2.68798308 1.96073356 2.85446277 5.88067607 6.2067228  2.01749054
#  2.12620868 5.50409991 0.71337671 0.20694786 9.97193829 2.89348029
#  1.0998101  0.06914653 1.91608007 0.32558594 5.56948967 1.32544309
#  5.60013311 5.72849102]
#
#  Fatigue
# [4.11666147 5.49525654 6.54699346 5.41828894 4.48836531 3.12407892
#  4.06671925 4.9438631  3.03051412 3.77937742 4.10981933 3.22266811
#  9.18822662 7.95272684 2.87509991 2.17821406 5.7867292  3.66565074
# ...

# %%
X = df[[
    "Fever",
    "Headache",
    "Cough",
    "Fatigue",
    "Body_Pain"
]]

X
# Out:
#            Fever  Headache     Cough   Fatigue  Body_Pain
# 0      98.283156  4.118632  2.687983  4.116661   8.470956
# 1      98.284660  6.963971  1.960734  5.495257   8.033919
# 2     103.622552  8.702915  2.854463  6.546993   2.205383
# 3      98.254732  1.354851  5.880676  5.418289   2.695560
# 4      97.182670  0.357962  6.206723  4.488365   1.406323
# ...          ...       ...       ...       ...        ...
# 4995   99.497722  2.172020  0.586186  4.632525   1.605553
# 4996  101.723742  5.895228  2.136698  4.763550   1.093120
# 4997  103.112569  7.834451  1.006200  9.094380   5.438879
# 4998   97.432053  1.613986  1.826666  2.089975   1.247891
# 4999   97.661094  1.994773  5.155273  4.701630   1.799597
#
# [5000 rows x 5 columns]

# %%
y = df["Disease"]

y
# Out:
# 0          Body Ache
# 1          Body Ache
# 2            Malaria
# 3        Common Cold
# 4              Cough
#             ...
# 4995    Normal Fever
# 4996    Normal Fever
# 4997          Dengue
# 4998      Runny Nose
# 4999     Common Cold
# Name: Disease, Length: 5000, dtype: object

# %%
print("X shape:", X.shape)
print("y shape:", y.shape)

print("\nInput features:")
print(X.head())

print("\nTarget:")
print(y.head())
# Out:
# X shape: (5000, 5)
# y shape: (5000,)
#
# Input features:
#         Fever  Headache     Cough   Fatigue  Body_Pain
# 0   98.283156  4.118632  2.687983  4.116661   8.470956
# 1   98.284660  6.963971  1.960734  5.495257   8.033919
# 2  103.622552  8.702915  2.854463  6.546993   2.205383
# 3   98.254732  1.354851  5.880676  5.418289   2.695560
# 4   97.182670  0.357962  6.206723  4.488365   1.406323
#
# Target:
# 0      Body Ache
# 1      Body Ache
# 2        Malaria
# 3    Common Cold
# 4          Cough
# Name: Disease, dtype: object

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    test_size=0.20,
    random_state=42,
    stratify=y
)

print("Training data:", X_train.shape)
print("Testing data:", X_test.shape)
# Out:
# Training data: (4000, 5)
# Testing data: (1000, 5)

# %%
from sklearn.metrics import accuracy_score

y_pred = model.predict(X_test)

accuracy = accuracy_score(y_test, y_pred)

print("Accuracy:", accuracy)
print("Accuracy %:", accuracy * 100)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_3327/1878275061.py in <cell line: 0>()
#       1 from sklearn.metrics import accuracy_score
#       2
# ----> 3 y_pred = model.predict(X_test)
#       4
#       5 accuracy = accuracy_score(y_test, y_pred)
#
# NameError: name 'model' is not defined

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression

# Step 1: Create scaler
scaler = StandardScaler()

# Step 2: Scale training data
X_train_scaled = scaler.fit_transform(X_train)

# Step 3: Scale test data
X_test_scaled = scaler.transform(X_test)

# Step 4: Create Logistic Regression model
model = LogisticRegression(max_iter=2000)

# Step 5: Train model
model.fit(X_train_scaled, y_train)

print("Model trained successfully!")

# %%
y_pred = model.predict(X_test_scaled)

# %%
y_pred

# %%
X_test_scaled = scaler.transform(X_test)

# %%
X_test_scaled

# %%
from sklearn.metrics import accuracy_score

accuracy = accuracy_score(y_test, y_pred)

print("Accuracy:", accuracy)
print("Accuracy %:", accuracy * 100)

# %%
from sklearn.metrics import classification_report

print(classification_report(y_test, y_pred))

# %%
import joblib

joblib.dump(model, "health_model.pkl")
joblib.dump(scaler, "health_scaler.pkl")

print("Model and scaler saved successfully!")

# %%
import os

print(os.listdir())
